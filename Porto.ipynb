# %% [markdown]
# ## Importing the input vectors

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
import tensorflow as tf
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.models import Model
from tensorflow.keras import backend as K
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Run the data preparation notebook
X_analog_feb = pd.DataFrame(np.load("npy_files/X_analog_feb.npy"))
X_analog_may_june = pd.DataFrame(np.load("npy_files/X_analog_may_june.npy"))

# %%
X_analog_may_june.head()
# Out:
#          0         1         2         3         4         5         6   \
# 0 -0.014776  0.139931  0.396183  0.391436  0.342122  0.226712 -0.021780
# 1 -0.094405  0.196174  0.399288  0.406951  0.322616  0.203375 -0.024953
# 2  0.045894  0.152430  0.399288  0.410830  0.332369  0.203375 -0.034472
# 3  0.315116  0.661743  0.421024  0.441858  0.361629  0.232546 -0.021780
# 4  0.095188  0.486764  0.417919  0.430223  0.356752  0.232546 -0.018607
#
#          7         8         9         10        11        12        13  \
# 0  0.160426 -0.246660 -0.742034  0.172732 -0.822266 -0.464341 -0.432601
# 1  0.377741  0.638057 -0.096832  0.375188 -0.821126 -0.464341 -0.432601
# 2  0.479154  0.427705 -0.162819  0.260562 -0.822266 -0.464341 -0.432601
# 3  0.526239  0.724673 -0.155487  0.250141 -0.821126 -0.463069 -0.431200
# 4  0.533483  0.588562 -0.144489  0.300755 -0.821126 -0.463069 -0.431200
#
#          14        15   16
# 0 -0.047292  0.012358  0.0
# 1 -0.044720  0.014667  0.0
# 2 -0.047292  0.014457  0.0
# 3 -0.042149  0.014877  0.0
# 4 -0.044720  0.014457  0.0

# %% [markdown]
# #### Divide into train data and test data

# %%
raw_data_may_june = X_analog_may_june.values

# %%
# The last element contains the labels
labels = raw_data_may_june[:, -1]

# The other data points are the data
data = raw_data_may_june[:, 0:-1]

train_data_may_june, test_data_may_june, train_labels_may_june, test_labels_may_june = train_test_split(
    data, labels, test_size=0.2, shuffle=True, random_state=21
)

train_data_may_june = tf.cast(train_data_may_june, tf.float32)
test_data_may_june = tf.cast(test_data_may_june, tf.float32)

train_labels_may_june = train_labels_may_june.astype(bool)
test_labels_may_june = test_labels_may_june.astype(bool)

normal_train_data_may_june = train_data_may_june[~train_labels_may_june]
normal_test_data_may_june = test_data_may_june[~test_labels_may_june]

anomalous_train_data_may_june = train_data_may_june[train_labels_may_june]
anomalous_test_data_may_june = test_data_may_june[test_labels_may_june]

# %% [markdown]
# ## Autoencoder

# %%
# Define input dimension
input_dim = normal_train_data_may_june.shape[1]

# Encoder: Three layers plus bottleneck
input_layer = Input(shape=(input_dim,), name='input')
encoded = Dense(128, activation='relu', name='encoder_layer1')(input_layer)
encoded = Dense(64, activation='relu', name='encoder_layer2')(encoded)
encoded = Dense(32, activation='relu', name='encoder_layer3')(encoded)
bottleneck = Dense(12, activation='relu', name='bottleneck')(encoded)

# Decoder: Three layers mirroring the encoder
decoded = Dense(32, activation='relu', name='decoder_layer1')(bottleneck)
decoded = Dense(64, activation='relu', name='decoder_layer2')(decoded)
decoded = Dense(128, activation='relu', name='decoder_layer3')(decoded)
output_layer = Dense(input_dim, activation='sigmoid', name='output')(decoded)


autoencoder = Model(input_layer, output_layer)

# Custom loss function class
class SparseAutoencoderLoss(tf.keras.losses.Loss):
    def __init__(self, model, lambda_reg=1e-3, beta=1e-5, sparsity_target=0.05):
        super(SparseAutoencoderLoss, self).__init__()
        self.model = model
        self.lambda_reg = lambda_reg
        self.beta = beta
        self.sparsity_target = sparsity_target

    def get_layer_activations(self, data):
        layer_outputs = [layer.output for layer in self.model.layers if 'encoder' in layer.name or 'decoder' in layer.name or 'bottleneck' in layer.name]
        activation_model = Model(inputs=self.model.input, outputs=layer_outputs)
        activations = activation_model(data)
        return activations

    def call(self, y_true, y_pred):
        # Mean Squared Error
        mse_loss = tf.reduce_mean(tf.square(y_true - y_pred))

        # Frobenius norm
        frobenius_loss = 0
        for layer in self.model.layers:
            if hasattr(layer, 'kernel'):
                frobenius_loss += tf.reduce_sum(tf.square(layer.kernel))
        frobenius_loss *= self.lambda_reg

        # Kullback-Leibler divergence
        activations = self.get_layer_activations(y_true)
        kl_divergence = 0
        for activation in activations:
            rho_hat = tf.reduce_mean(activation, axis=0)  # Average activation per neuron
            kl_divergence += tf.reduce_sum( #reduce_sum takes the entire rho_hat vector and sums it up in the formula
            0.01 * tf.math.log(0.01 / (rho_hat + 1e-7)) +
            (1 - 0.01) * tf.math.log((1 - 0.01) / (1 - rho_hat + 1e-7))
            )
        kl_loss = self.beta * kl_divergence

        # Total loss
        return mse_loss + frobenius_loss + kl_loss

# Compile the model with the custom loss
autoencoder.compile(
    optimizer=tf.keras.optimizers.Adam(),#learning_rate=0.01),
    loss=SparseAutoencoderLoss(model=autoencoder, lambda_reg=1e-5, beta=5, sparsity_target=0.01)
)

# Train the model
history = autoencoder.fit(
    x=normal_train_data_may_june,  # Input and target are the same for autoencoders
    y=normal_train_data_may_june,  # Input and target are the same for autoencoders
    epochs=100, 
    batch_size=30, 
    validation_data=(normal_test_data_may_june, normal_test_data_may_june)
)

# Plot training and validation loss
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.legend()
plt.title('Loss Over Epochs')
plt.show()
# Out:
# Epoch 1/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 75.9827 - val_loss: 23.7094
# Epoch 2/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 16.9686 - val_loss: 13.8626
# Epoch 3/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 8.0840 - val_loss: 10.8959
# Epoch 4/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 6.8374 - val_loss: 9.3580
# Epoch 5/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 5.2991 - val_loss: 8.1502
# Epoch 6/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 4.0007 - val_loss: 7.2569
# Epoch 7/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.5445 - val_loss: 6.6227
# Epoch 8/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 3.0999 - val_loss: 6.2760
# Epoch 9/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.8278 - val_loss: 5.9565
# Epoch 10/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.5454 - val_loss: 5.5968
# Epoch 11/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.2604 - val_loss: 5.4613
# Epoch 12/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.2357 - val_loss: 5.1586
# Epoch 13/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2.0815 - val_loss: 4.9952
# Epoch 14/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.7552 - val_loss: 4.8305
# Epoch 15/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.7895 - val_loss: 4.6356
# Epoch 16/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.5601 - val_loss: 4.6689
# Epoch 17/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.6501 - val_loss: 4.4967
# Epoch 18/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.6653 - val_loss: 4.5399
# Epoch 19/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.8147 - val_loss: 4.3576
# Epoch 20/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.6712 - val_loss: 4.1352
# Epoch 21/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.4802 - val_loss: 4.1885
# Epoch 22/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.4645 - val_loss: 4.2027
# Epoch 23/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.3986 - val_loss: 4.0398
# Epoch 24/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.3262 - val_loss: 4.0792
# Epoch 25/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.3118 - val_loss: 3.9205
# Epoch 26/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.1522 - val_loss: 3.9113
# Epoch 27/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.4844 - val_loss: 3.7886
# Epoch 28/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.1704 - val_loss: 3.7678
# Epoch 29/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.3068 - val_loss: 3.8279
# Epoch 30/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3648 - val_loss: 3.7068
# Epoch 31/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.3152 - val_loss: 3.7624
# Epoch 32/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.2381 - val_loss: 3.6853
# Epoch 33/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.2990 - val_loss: 3.6404
# Epoch 34/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.1842 - val_loss: 3.5865
# Epoch 35/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.1565 - val_loss: 3.5636
# Epoch 36/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.1572 - val_loss: 3.5271
# Epoch 37/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0630 - val_loss: 3.5412
# Epoch 38/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.1642 - val_loss: 3.5406
# Epoch 39/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0821 - val_loss: 3.4566
# Epoch 40/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.1937 - val_loss: 3.4848
# Epoch 41/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.2095 - val_loss: 3.4393
# Epoch 42/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.2577 - val_loss: 3.4297
# Epoch 43/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.1761 - val_loss: 3.3980
# Epoch 44/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.1810 - val_loss: 3.3360
# Epoch 45/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.2351 - val_loss: 3.3514
# Epoch 46/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.1611 - val_loss: 3.2797
# Epoch 47/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.1523 - val_loss: 3.2410
# Epoch 48/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.1417 - val_loss: 3.2547
# Epoch 49/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0575 - val_loss: 3.3101
# Epoch 50/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0513 - val_loss: 3.1687
# Epoch 51/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.1702 - val_loss: 3.1760
# Epoch 52/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.1632 - val_loss: 3.1633
# Epoch 53/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0339 - val_loss: 3.1177
# Epoch 54/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0431 - val_loss: 3.0266
# Epoch 55/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.9668 - val_loss: 3.0212
# Epoch 56/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0727 - val_loss: 3.0395
# Epoch 57/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0504 - val_loss: 2.9598
# Epoch 58/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.9685 - val_loss: 2.9690
# Epoch 59/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.9949 - val_loss: 2.9269
# Epoch 60/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.0661 - val_loss: 2.8767
# Epoch 61/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.0143 - val_loss: 2.8794
# Epoch 62/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.1071 - val_loss: 2.9246
# Epoch 63/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0224 - val_loss: 2.8366
# Epoch 64/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0005 - val_loss: 2.8374
# Epoch 65/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0157 - val_loss: 2.8051
# Epoch 66/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.9207 - val_loss: 2.8691
# Epoch 67/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.9716 - val_loss: 2.6726
# Epoch 68/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.9417 - val_loss: 2.6861
# Epoch 69/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.9077 - val_loss: 2.7021
# Epoch 70/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0188 - val_loss: 2.7134
# Epoch 71/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.8820 - val_loss: 2.6040
# Epoch 72/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0291 - val_loss: 2.6100
# Epoch 73/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.8881 - val_loss: 2.5931
# Epoch 74/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.9258 - val_loss: 2.5874
# Epoch 75/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.8821 - val_loss: 2.4499
# Epoch 76/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0042 - val_loss: 2.4120
# Epoch 77/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.9229 - val_loss: 2.4052
# Epoch 78/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.8847 - val_loss: 2.3945
# Epoch 79/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.8644 - val_loss: 2.3789
# Epoch 80/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.8337 - val_loss: 2.3653
# Epoch 81/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.8981 - val_loss: 2.3218
# Epoch 82/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.8868 - val_loss: 2.3990
# Epoch 83/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.8707 - val_loss: 2.2968
# Epoch 84/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.9540 - val_loss: 2.2585
# Epoch 85/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.9072 - val_loss: 2.2913
# Epoch 86/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.8684 - val_loss: 2.2777
# Epoch 87/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.8632 - val_loss: 2.2255
# Epoch 88/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.8803 - val_loss: 2.1915
# Epoch 89/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.7987 - val_loss: 2.2167
# Epoch 90/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.8052 - val_loss: 2.1539
# Epoch 91/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.8207 - val_loss: 2.1644
# Epoch 92/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.9255 - val_loss: 2.0956
# Epoch 93/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.9279 - val_loss: 2.1796
# Epoch 94/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.7656 - val_loss: 2.1115
# Epoch 95/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.8153 - val_loss: 2.1052
# Epoch 96/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.9244 - val_loss: 2.0756
# Epoch 97/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.9046 - val_loss: 2.0834
# Epoch 98/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.8364 - val_loss: 2.1467
# Epoch 99/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.9017 - val_loss: 2.0877
# Epoch 100/100
# 79/79 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.7491 - val_loss: 2.0702

# %%
# Classify an ECG as anomalous if the reconstruction error is greater than one standard deviation
reconstructions_normal = autoencoder.predict(normal_train_data_may_june)
train_loss = tf.keras.losses.mae(reconstructions_normal, normal_train_data_may_june)

threshold = np.mean(train_loss) + np.std(train_loss)
print("Threshold: ", threshold)
threshold=1 ########################################################################################################################################################

reconstructions_anomalous = autoencoder.predict(anomalous_test_data_may_june)
test_loss = tf.keras.losses.mae(reconstructions_anomalous, anomalous_test_data_may_june)

# Plot both losses on the same histogram
plt.hist(train_loss, bins=50, alpha=0.6, color='blue', label='Normal')
plt.hist(test_loss, bins=50, alpha=0.6, color='red', label='Anomalous')

plt.xlabel("Reconstruction Loss")
plt.ylabel("Number of Examples")
plt.legend(loc='upper right')
plt.title("Reconstruction Loss for Normal and Anomalous ECGs")
plt.ylim((0, 40))
plt.show()


# Classify an ECG as an anomaly if the reconstruction error is greater than the threshold.
def predict(model, data, threshold):
    reconstructions = model(data)
    loss = tf.keras.losses.mae(reconstructions, data)
    return tf.math.less(loss, threshold)

def print_stats(predictions, labels):
    print("Accuracy = {}%".format(100*accuracy_score(~labels, predictions)))
    print("Precision = {}%".format(100*precision_score(~labels, predictions)))
    print("Recall = {}%".format(100*recall_score(~labels, predictions)))
    print("F1 Score = {}%".format(100*f1_score(~labels, predictions)))

preds = predict(autoencoder, test_data_may_june, threshold)
print_stats(preds, test_labels_may_june)
# Out:
# 74/74 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Threshold:  0.61864054
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# Accuracy = 97.80701754385966%
# Precision = 99.82425307557118%
# Recall = 97.59450171821305%
# F1 Score = 98.69678540399653%

# %%
from sklearn.metrics import confusion_matrix

# Generate the confusion matrix
cm = confusion_matrix(~test_labels_may_june, preds)

print("Confusion Matrix:")
print(cm)
# Out:
# Confusion Matrix:
# [[101   1]
#  [ 14 568]]

# %% [markdown]
# ### Training and validating with February. Evaluating on May/June

# %% [markdown]
# ### ____________________________________________________________________________________________________________________________________________________________

# %%
raw_data_feb = X_analog_feb.values

# %%
# The other data points are the data
data = raw_data_feb

train_data_feb, test_data_feb = train_test_split(
    data, test_size=0.2, shuffle=True, random_state=21
)

train_data_feb = tf.cast(train_data_feb, tf.float32)
test_data_feb = tf.cast(test_data_feb, tf.float32)

# %%
# Define input dimension
input_dim = train_data_feb.shape[1]

# Encoder: Three layers plus bottleneck
input_layer = Input(shape=(input_dim,), name='input')
encoded = Dense(128, activation='relu', name='encoder_layer1')(input_layer)
encoded = Dense(64, activation='relu', name='encoder_layer2')(encoded)
encoded = Dense(32, activation='relu', name='encoder_layer3')(encoded)
bottleneck = Dense(12, activation='relu', name='bottleneck')(encoded)

# Decoder: Three layers mirroring the encoder
decoded = Dense(32, activation='relu', name='decoder_layer1')(bottleneck)
decoded = Dense(64, activation='relu', name='decoder_layer2')(decoded)
decoded = Dense(128, activation='relu', name='decoder_layer3')(decoded)
output_layer = Dense(input_dim, activation='sigmoid', name='output')(decoded)


autoencoder = Model(input_layer, output_layer)

# Custom loss function class
class SparseAutoencoderLoss(tf.keras.losses.Loss):
    def __init__(self, model, lambda_reg=1e-3, beta=1e-5, sparsity_target=0.05):
        super(SparseAutoencoderLoss, self).__init__()
        self.model = model
        self.lambda_reg = lambda_reg
        self.beta = beta
        self.sparsity_target = sparsity_target

    def get_layer_activations(self, data):
        layer_outputs = [layer.output for layer in self.model.layers if 'encoder' in layer.name or 'decoder' in layer.name or 'bottleneck' in layer.name]
        activation_model = Model(inputs=self.model.input, outputs=layer_outputs)
        activations = activation_model(data)
        return activations

    def call(self, y_true, y_pred):
        # Mean Squared Error
        mse_loss = tf.reduce_mean(tf.square(y_true - y_pred))

        # Frobenius norm
        frobenius_loss = 0
        for layer in self.model.layers:
            if hasattr(layer, 'kernel'):
                frobenius_loss += tf.reduce_sum(tf.square(layer.kernel))
        frobenius_loss *= self.lambda_reg

        # Kullback-Leibler divergence
        activations = self.get_layer_activations(y_true)
        kl_divergence = 0
        for activation in activations:
            rho_hat = tf.reduce_mean(activation, axis=0)  # Average activation per neuron
            kl_divergence += tf.reduce_sum( #reduce_sum takes the entire rho_hat vector and sums it up in the formula
            0.01 * tf.math.log(0.01 / (rho_hat + 1e-7)) +
            (1 - 0.01) * tf.math.log((1 - 0.01) / (1 - rho_hat + 1e-7))
            )
        kl_loss = self.beta * kl_divergence

        # Total loss
        return mse_loss + frobenius_loss + kl_loss

# Compile the model with the custom loss
autoencoder.compile(
    optimizer=tf.keras.optimizers.Adam(),#learning_rate=0.01),
    loss=SparseAutoencoderLoss(model=autoencoder, lambda_reg=1e-5, beta=5, sparsity_target=0.01)
)

# Train the model
history = autoencoder.fit(
    x=train_data_feb,  # Input and target are the same for autoencoders
    y=train_data_feb,  # Input and target are the same for autoencoders
    epochs=100, 
    batch_size=30, 
    validation_data=(test_data_feb, test_data_feb)
)

# Plot training and validation loss
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.legend()
plt.title('Loss Over Epochs')
plt.show()
# Out:
# Epoch 1/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 143.3393 - val_loss: 85.8980
# Epoch 2/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 70.8768 - val_loss: 64.3059
# Epoch 3/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 55.3434 - val_loss: 51.3084
# Epoch 4/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 41.3157 - val_loss: 40.9866
# Epoch 5/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 33.7319 - val_loss: 33.1242
# Epoch 6/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 24.7231 - val_loss: 27.1060
# Epoch 7/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 22.5261 - val_loss: 22.2783
# Epoch 8/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 16.5408 - val_loss: 18.6341
# Epoch 9/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 14.2668 - val_loss: 15.7435
# Epoch 10/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 11.5137 - val_loss: 13.6090
# Epoch 11/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 10.1867 - val_loss: 11.7433
# Epoch 12/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 9.0549 - val_loss: 10.3414
# Epoch 13/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 7.8665 - val_loss: 9.2605
# Epoch 14/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 7.1662 - val_loss: 7.7919
# Epoch 15/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 5.3201 - val_loss: 6.9309
# Epoch 16/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.7723 - val_loss: 6.2098
# Epoch 17/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.1013 - val_loss: 5.6871
# Epoch 18/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.3296 - val_loss: 5.2060
# Epoch 19/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.1784 - val_loss: 4.8410
# Epoch 20/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.0391 - val_loss: 4.5853
# Epoch 21/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.3376 - val_loss: 4.4071
# Epoch 22/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.3219 - val_loss: 4.0918
# Epoch 23/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.3850 - val_loss: 3.8648
# Epoch 24/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.1739 - val_loss: 3.7044
# Epoch 25/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.0892 - val_loss: 3.6588
# Epoch 26/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.8317 - val_loss: 3.6512
# Epoch 27/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.0376 - val_loss: 3.5684
# Epoch 28/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.8216 - val_loss: 3.5441
# Epoch 29/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.0742 - val_loss: 3.4314
# Epoch 30/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.1746 - val_loss: 3.3815
# Epoch 31/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.0787 - val_loss: 3.3370
# Epoch 32/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.7479 - val_loss: 3.2153
# Epoch 33/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.8158 - val_loss: 3.3091
# Epoch 34/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.1745 - val_loss: 3.1399
# Epoch 35/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.7835 - val_loss: 3.0305
# Epoch 36/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.7061 - val_loss: 3.0234
# Epoch 37/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.7728 - val_loss: 3.0086
# Epoch 38/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.8689 - val_loss: 2.9537
# Epoch 39/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.5914 - val_loss: 2.9223
# Epoch 40/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.7774 - val_loss: 2.9587
# Epoch 41/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.5344 - val_loss: 2.8980
# Epoch 42/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.7561 - val_loss: 2.8479
# Epoch 43/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.5095 - val_loss: 2.8412
# Epoch 44/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.8951 - val_loss: 2.7763
# Epoch 45/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.6623 - val_loss: 2.8328
# Epoch 46/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.7147 - val_loss: 2.7526
# Epoch 47/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.3126 - val_loss: 2.8113
# Epoch 48/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.4493 - val_loss: 2.7828
# Epoch 49/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.4600 - val_loss: 2.6390
# Epoch 50/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.3457 - val_loss: 2.5722
# Epoch 51/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.3843 - val_loss: 2.6058
# Epoch 52/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.3198 - val_loss: 2.6310
# Epoch 53/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.1951 - val_loss: 2.5424
# Epoch 54/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.2488 - val_loss: 2.5548
# Epoch 55/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.4395 - val_loss: 2.5002
# Epoch 56/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.4298 - val_loss: 2.5505
# Epoch 57/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.3266 - val_loss: 2.6474
# Epoch 58/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.6537 - val_loss: 2.7518
# Epoch 59/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.4770 - val_loss: 2.6883
# Epoch 60/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.5402 - val_loss: 2.8110
# Epoch 61/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.4741 - val_loss: 2.7470
# Epoch 62/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.0257 - val_loss: 2.6336
# Epoch 63/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.2923 - val_loss: 2.5061
# Epoch 64/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.2402 - val_loss: 2.4969
# Epoch 65/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.2423 - val_loss: 2.6221
# Epoch 66/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.4029 - val_loss: 2.5370
# Epoch 67/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.3287 - val_loss: 2.5953
# Epoch 68/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.2112 - val_loss: 2.5941
# Epoch 69/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.2580 - val_loss: 2.4829
# Epoch 70/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.4661 - val_loss: 2.5372
# Epoch 71/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.5507 - val_loss: 2.5473
# Epoch 72/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.3497 - val_loss: 2.4961
# Epoch 73/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.2073 - val_loss: 2.5459
# Epoch 74/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.1870 - val_loss: 2.5323
# Epoch 75/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.2491 - val_loss: 2.6595
# Epoch 76/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.5381 - val_loss: 2.6891
# Epoch 77/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.1255 - val_loss: 2.5733
# Epoch 78/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.1770 - val_loss: 2.4649
# Epoch 79/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.3649 - val_loss: 2.5119
# Epoch 80/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.0135 - val_loss: 2.5799
# Epoch 81/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.1845 - val_loss: 2.3881
# Epoch 82/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.0061 - val_loss: 2.3368
# Epoch 83/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.9521 - val_loss: 2.3390
# Epoch 84/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.2357 - val_loss: 2.3754
# Epoch 85/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.2045 - val_loss: 2.4526
# Epoch 86/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.3068 - val_loss: 2.6054
# Epoch 87/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.2157 - val_loss: 2.6177
# Epoch 88/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.1212 - val_loss: 2.6104
# Epoch 89/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.2097 - val_loss: 2.5721
# Epoch 90/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.3371 - val_loss: 2.5671
# Epoch 91/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.1901 - val_loss: 2.4342
# Epoch 92/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.0372 - val_loss: 2.3897
# Epoch 93/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.0901 - val_loss: 2.3881
# Epoch 94/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.1622 - val_loss: 2.4359
# Epoch 95/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.2116 - val_loss: 2.3298
# Epoch 96/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.8935 - val_loss: 2.2029
# Epoch 97/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.0417 - val_loss: 2.3499
# Epoch 98/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.2080 - val_loss: 2.1529
# Epoch 99/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.9857 - val_loss: 2.1680
# Epoch 100/100
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 2.0899 - val_loss: 2.1617

# %%
# Classify an ECG as anomalous if the reconstruction error is greater than one standard deviation
reconstructions_normal = autoencoder.predict(train_data_feb)
train_loss = tf.keras.losses.mae(reconstructions_normal, train_data_feb)

threshold = np.mean(train_loss) + np.std(train_loss)
print("Threshold: ", threshold)
threshold=1.3 ########################################################################################################################################################

reconstructions_anomalous = autoencoder.predict(anomalous_test_data_may_june)
test_loss = tf.keras.losses.mae(reconstructions_anomalous, anomalous_test_data_may_june)

# Plot both losses on the same histogram
plt.hist(train_loss, bins=50, alpha=0.6, color='blue', label='Normal')
plt.hist(test_loss, bins=50, alpha=0.6, color='red', label='Anomalous')

plt.xlabel("Reconstruction Loss")
plt.ylabel("Number of Examples")
plt.legend(loc='upper right')
plt.title("Reconstruction Loss for Normal and Anomalous ECGs")
#plt.ylim((0, 40))
plt.show()


# Classify an ECG as an anomaly if the reconstruction error is greater than the threshold.
def predict(model, data, threshold):
    reconstructions = model(data)
    loss = tf.keras.losses.mae(reconstructions, data)
    return tf.math.less(loss, threshold)

def print_stats(predictions, labels):
    print("Accuracy = {}%".format(100*accuracy_score(~labels, predictions)))
    print("Precision = {}%".format(100*precision_score(~labels, predictions)))
    print("Recall = {}%".format(100*recall_score(~labels, predictions)))
    print("F1 Score = {}%".format(100*f1_score(~labels, predictions)))

preds = predict(autoencoder, test_data_may_june, threshold)
print_stats(preds, test_labels_may_june)
# Out:
# 29/29 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Threshold:  0.9869408
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Accuracy = 97.80701754385966%
# Precision = 98.96373056994818%
# Recall = 98.4536082474227%
# F1 Score = 98.70801033591732%
